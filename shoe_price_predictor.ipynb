# %% [markdown]
# ## Shoe Price Predictor

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier 
from sklearn.preprocessing import FunctionTransformer
from sklearn.metrics import r2_score , mean_squared_error
import joblib
sns.set_palette(palette='viridis')

# %%
df = pd.read_csv('Shoe_Data.csv')
df.head()
# Out:
#    Order Date   Brand                                   Sneaker Name  \
# 0  2017-09-01   Yeezy           Adidas Yeezy Boost 350 Low V2 Beluga
# 1  2017-09-01   Yeezy    Adidas Yeezy Boost 350 V2 Core Black Copper
# 2  2017-09-01   Yeezy     Adidas Yeezy Boost 350 V2 Core Black Green
# 3  2017-09-01   Yeezy       Adidas Yeezy Boost 350 V2 Core Black Red
# 4  2017-09-01   Yeezy  Adidas Yeezy Boost 350 V2 Core Black Red 2017
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region
# 0        1097           220   2016-09-24       11.0    California
# 1         685           220   2016-11-23       11.0    California
# 2         690           220   2016-11-23       11.0    California
# 3        1075           220   2016-11-23       11.5      Kentucky
# 4         828           220   2017-02-11       11.0  Rhode Island

# %%
df.shape
# Out:
# (99956, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99956 entries, 0 to 99955
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    99956 non-null  object
#  1   Brand         99956 non-null  object
#  2   Sneaker Name  99956 non-null  object
#  3   Sale Price    99956 non-null  int64
#  4   Retail Price  99956 non-null  int64
#  5   Release Date  99956 non-null  object
#  6   Shoe Size     99956 non-null  float64
#  7   Buyer Region  99956 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.1+ MB

# %%
df.isna().sum()
# Out:
# Order Date      0
# Brand           0
# Sneaker Name    0
# Sale Price      0
# Retail Price    0
# Release Date    0
# Shoe Size       0
# Buyer Region    0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#        Order Date      Brand                           Sneaker Name  \
# 994    2017-10-13      Yeezy  Adidas Yeezy Boost 350 V2 Cream White
# 1028   2017-10-13      Yeezy        Adidas Yeezy Boost 350 V2 Zebra
# 1513   2017-11-09  Off-White              Nike Blazer Mid Off White
# 1531   2017-11-10      Yeezy  Adidas Yeezy Boost 350 V2 Cream White
# 1619   2017-11-11  Off-White              Nike Air Presto Off White
# ...           ...        ...                                    ...
# 99815  2019-02-13  Off-White   Nike Air Max 90 Off White Desert Ore
# 99882  2019-02-13      Yeezy       adidas Yeezy Boost 350 V2 Butter
# 99907  2019-02-13      Yeezy       adidas Yeezy Boost 350 V2 Static
# 99924  2019-02-13      Yeezy       adidas Yeezy Boost 350 V2 Static
# 99926  2019-02-13      Yeezy       adidas Yeezy Boost 350 V2 Static
#
#        Sale Price  Retail Price Release Date  Shoe Size Buyer Region
# 994           425           220   2017-04-29       10.5     Illinois
# 1028          560           220   2017-02-25        8.5   California
# 1513          550           130   2017-09-09        9.0   California
# 1531          460           220   2017-04-29       10.0   California
# 1619          975           160   2017-09-09       10.0   California
# ...           ...           ...          ...        ...          ...
# 99815         520           160   2019-02-07        9.0       Oregon
# 99882         228           220   2018-06-30        9.0       Oregon
# 99907         350           220   2018-12-27        9.5       Oregon
# 99924         330           220   2018-12-27        9.0       Oregon
# 99926         330           220   2018-12-27       10.0       Oregon
#
# [2840 rows x 8 columns]

# %%
df.drop_duplicates(keep='first' , inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order Date, Brand, Sneaker Name, Sale Price, Retail Price, Release Date, Shoe Size, Buyer Region]
# Index: []

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'] )

# %%
plt.figure(figsize=(14,5))
sns.histplot(df['Order Date'] , kde = True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.histplot(df['Brand'] )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.histplot(df['Sale Price'] , kde=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Mostly all the prices are uptill 1200**

# %%
sns.boxplot(x = df['Sale Price'] )
# Out:
# <Axes: xlabel='Sale Price'>

# %%
df[df['Sale Price'] > 1000].count()
# Out:
# Order Date      2985
# Brand           2985
# Sneaker Name    2985
# Sale Price      2985
# Retail Price    2985
# Release Date    2985
# Shoe Size       2985
# Buyer Region    2985
# dtype: int64

# %%
#lets drop these outliers 
df = df[~(df['Sale Price'] > 1000)]

# %%
df[df['Sale Price'] > 1000].count()
# Out:
# Order Date      0
# Brand           0
# Sneaker Name    0
# Sale Price      0
# Retail Price    0
# Release Date    0
# Shoe Size       0
# Buyer Region    0
# dtype: int64

# %%
plt.figure(figsize=(14,5))
sns.histplot(df['Retail Price'] , kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.histplot(df['Shoe Size'] , kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(df['Shoe Size'])
# Out:
# <Axes: ylabel='Shoe Size'>

# %%
# anything above size 14 is an outlier also we will take lowerlimit as 4

df = df[~ ( (df['Shoe Size'] > 14) & (df['Shoe Size'] > 14) )]

# %%
df[(df['Shoe Size'] > 14) & (df['Shoe Size'] > 14)]
# Out:
# Empty DataFrame
# Columns: [Order Date, Brand, Sneaker Name, Sale Price, Retail Price, Release Date, Shoe Size, Buyer Region]
# Index: []

# %%
plt.figure(figsize=(14,5))
sns.histplot(df['Buyer Region'] , kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
# since there will be many columns in dummy encoding for sneaker name lets extract first three letters only

# Split the sneaker name into words and join the first three words
df['Sneaker Name'] = df['Sneaker Name'].apply(lambda x: ' '.join(x.split()[:3]))

# %%
df['Sneaker Name'].value_counts()
# Out:
# Sneaker Name
# Adidas Yeezy Boost      50780
# adidas Yeezy Boost      18319
# Nike Zoom Fly            4256
# Nike Air Presto          3854
# Air Jordan 1             3771
# Nike Blazer Mid          3501
# Nike Air VaporMax        3289
# Nike Air Max             3253
# Nike Air Force           2356
# Nike React Hyperdunk      482
# Name: count, dtype: int64

# %%
df["Brand"].value_counts()
# Out:
# Brand
#  Yeezy       69099
# Off-White    24762
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Order Date   Brand        Sneaker Name  Sale Price  Retail Price  \
# 1 2017-09-01   Yeezy  Adidas Yeezy Boost         685           220
# 2 2017-09-01   Yeezy  Adidas Yeezy Boost         690           220
# 4 2017-09-01   Yeezy  Adidas Yeezy Boost         828           220
# 5 2017-09-01   Yeezy  Adidas Yeezy Boost         798           220
# 6 2017-09-01   Yeezy  Adidas Yeezy Boost         784           220
#
#   Release Date  Shoe Size  Buyer Region
# 1   2016-11-23       11.0    California
# 2   2016-11-23       11.0    California
# 4   2017-02-11       11.0  Rhode Island
# 5   2017-02-11        8.5      Michigan
# 6   2016-12-17       11.0    California

# %%
df['Sneaker Name'].value_counts()
# Out:
# Sneaker Name
# Adidas Yeezy Boost      50780
# adidas Yeezy Boost      18319
# Nike Zoom Fly            4256
# Nike Air Presto          3854
# Air Jordan 1             3771
# Nike Blazer Mid          3501
# Nike Air VaporMax        3289
# Nike Air Max             3253
# Nike Air Force           2356
# Nike React Hyperdunk      482
# Name: count, dtype: int64

# %%
df['Sneaker Name'] = df['Sneaker Name'].replace('adidas Yeezy Boost' , 'Adidas Yeezy Boost')

# %%
df['Sneaker Name'].value_counts()
# Out:
# Sneaker Name
# Adidas Yeezy Boost      69099
# Nike Zoom Fly            4256
# Nike Air Presto          3854
# Air Jordan 1             3771
# Nike Blazer Mid          3501
# Nike Air VaporMax        3289
# Nike Air Max             3253
# Nike Air Force           2356
# Nike React Hyperdunk      482
# Name: count, dtype: int64

# %%
import datetime as dt

df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Order Date']=df['Order Date'].map(dt.datetime.toordinal)

df['Release Date'] = pd.to_datetime(df['Release Date'])
df['Release Date']= df['Release Date'].map(dt.datetime.toordinal)

# %% [markdown]
# ### Model Building

# %%
y = df['Sale Price']
X = df.drop('Sale Price' , axis=1)

# %%
# applying train test split

X_train ,X_test,  y_train ,y_test = train_test_split(X , y , random_state=42 , train_size=0.7)

# %%
X_train
# Out:
#        Order Date      Brand        Sneaker Name  Retail Price  Release Date  \
# 20685      736768      Yeezy  Adidas Yeezy Boost           220        736371
# 21908      736783      Yeezy  Adidas Yeezy Boost           220        736658
# 54333      736979  Off-White     Nike Blazer Mid           130        736970
# 45521      736925  Off-White     Nike Air Presto           160        736902
# 98460      737100      Yeezy  Adidas Yeezy Boost           220        736658
# ...           ...        ...                 ...           ...           ...
# 6954       736667  Off-White       Nike Zoom Fly           170        736634
# 59116      737006  Off-White   Nike Air VaporMax           250        736783
# 82092      737056  Off-White       Nike Zoom Fly           170        736980
# 1043       736615      Yeezy  Adidas Yeezy Boost           220        736385
# 17027      736726      Yeezy  Adidas Yeezy Boost           220        736679
#
#        Shoe Size Buyer Region
# 20685        9.5   New Jersey
# 21908       10.0     New York
# 54333       12.0     New York
# 45521       12.0   California
# 98460        9.5   New Jersey
# ...          ...          ...
# 6954         9.0      Florida
# 59116        8.0   California
# 82092       11.5   California
# 1043        12.0      Arizona
# 17027       12.0     Maryland
#
# [65702 rows x 7 columns]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        # Converting dates into numericals with StandardScaler
        ('order_date', StandardScaler(), ['Order Date']),  # Apply StandardScaler to 'Order Date'
        ('release_date', StandardScaler(), ['Release Date']),  # Apply StandardScaler to 'Release Date'

        ('brand', OneHotEncoder(handle_unknown='ignore'), ['Brand']),
        ('sneaker_name', OneHotEncoder(handle_unknown='ignore'), ['Sneaker Name']),
        ('region', OneHotEncoder(handle_unknown='ignore'), ['Buyer Region']),
        ('size', StandardScaler(), ['Shoe Size']),
        ('retail', StandardScaler(), ['Retail Price'])
    ])

# %%
# Define the pipeline with preprocessing and model
pipeline_shoe = Pipeline(steps=[
    ('preprocessor', preprocessor),          # Apply the column transformers
    ('regressor', RandomForestRegressor())   # Apply the Random Forest model
])

# %%
# Fit the pipeline to the training data
pipeline_shoe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('order_date',
#                                                   StandardScaler(),
#                                                   ['Order Date']),
#                                                  ('release_date',
#                                                   StandardScaler(),
#                                                   ['Release Date']),
#                                                  ('brand',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Brand']),
#                                                  ('sneaker_name',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Sneaker Name']),
#                                                  ('region',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Buyer Region']),
#                                                  ('size', StandardScaler(),
#                                                   ['Shoe Size']),
#                                                  ('retail', StandardScaler(),
#                                                   ['Retail Price'])])),
#                 ('regressor', RandomForestRegressor())])

# %%
# Make predictions on the test set
y_pred = pipeline_shoe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9752962648821893

# %%
import pandas as pd
import datetime as dt

def predict_shoe_price(brand, sneaker_name, shoe_size, buyer_region, order_date, release_date, retail_price):
    # Create a DataFrame from the input arguments
    input_data = pd.DataFrame({
        'Brand': [brand],
        'Sneaker Name': [sneaker_name],
        'Shoe Size': [shoe_size],
        'Buyer Region': [buyer_region],
        'Order Date': [order_date],  # Ensure the date is in the correct format, e.g., YYYY-MM-DD
        'Release Date': [release_date],  # Same as above
        'Retail Price': [retail_price]  # This will not be used for prediction, but included for consistency
    })

    # Convert 'Order Date' and 'Release Date' to string, then to datetime
    input_data['Order Date'] = pd.to_datetime(input_data['Order Date'])
    input_data['Release Date'] = pd.to_datetime(input_data['Release Date'])

    # Convert the dates to ordinal values
    input_data['Order Date'] = input_data['Order Date'].map(dt.datetime.toordinal)
    input_data['Release Date'] = input_data['Release Date'].map(dt.datetime.toordinal)


    
    # Use the pipeline to predict the retail price
    predicted_price = pipeline_shoe.predict(input_data)  # Only pass feature columns to the pipeline
    
    return predicted_price[0]

# Example usage
brand = 'Yeezy'
sneaker_name = 'adidas Yeezy Boost 350'
shoe_size = 12.0
buyer_region = 'California'
order_date = '2024-11-01'  # Ensure the date is in YYYY-MM-DD format
release_date = '2024-01-01'  # Same as above
retail_price = 220.0  # Placeholder retail price

predicted_price = predict_shoe_price(brand, sneaker_name, shoe_size, buyer_region, order_date, release_date, retail_price)
print(f"The predicted retail price is: ${predicted_price:.2f}")
# Out:
# The predicted retail price is: $648.85

# %%
# Save the trained pipeline
joblib.dump(pipeline_shoe, 'pipeline_shoe.pkl')
# Out:
# ['pipeline_shoe.pkl']

# %%
X_train['Buyer Region'].unique()
# Out:
# array(['New Jersey', 'New York', 'California', 'Oregon', 'Washington',
#        'Idaho', 'Georgia', 'Texas', 'Florida', 'Alabama', 'Pennsylvania',
#        'Indiana', 'Virginia', 'North Carolina', 'Nevada', 'Oklahoma',
#        'Michigan', 'Arizona', 'New Mexico', 'Maryland', 'Illinois',
#        'Massachusetts', 'Ohio', 'Delaware', 'Connecticut', 'Wisconsin',
#        'Hawaii', 'Utah', 'Rhode Island', 'Minnesota', 'Missouri',
#        'South Carolina', 'Louisiana', 'Colorado', 'District of Columbia',
#        'New Hampshire', 'Kansas', 'Kentucky', 'Nebraska', 'West Virginia',
#        'Tennessee', 'Arkansas', 'South Dakota', 'Iowa', 'Maine',
#        'Wyoming', 'Alaska', 'Mississippi', 'Montana', 'Vermont',
#        'North Dakota'], dtype=object)
